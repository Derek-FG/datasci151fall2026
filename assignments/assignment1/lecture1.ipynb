# %% [markdown]
# ### Class Testing
# <font size = "5" color = "rgb(0,220,249)">
#
# What's cooking good looking
#
# ### Jira
# I've made some edits and will recommit with KAN-131 in the message.

# %%
print("Hello World")
# Out:
# Hello World
